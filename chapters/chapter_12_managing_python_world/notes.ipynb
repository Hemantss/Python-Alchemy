# %% [markdown]
# ***
# # Python Alchemy - Volume One
# # Chapter 12 - Managing Python World
#
# - 12.1 Why Structure Matters?
# - 12.2 Modules: The Structural Specification
# - 12.3 Understanding Namespace
# - 12.4 Namespaces Influence - Module Architecture
# - 12.5 Python’s Import System
# - 12.6 Python Packages: Organizing the Bigger Picture
# - 12.7 Top-level Code Environment
# - 12.8 Distributing and Reusing Packages
# - 12.9 Virtual Environments: Isolating Workflow
# - 12.10 Dependency and Version Management
# - 12.11 Managing Requirements
# - 12.12 Version Control Integration
#
# ***
